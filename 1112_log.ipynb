# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %%
import json
with open('./CONCH/who4e/for_demo/res_1112.json', 'r') as f:
    res = json.load(f)
    print("res_1112.json 第一個樣本:", res[0])
    print("caption 類型:", type(res[0].get('caption')))
    print("caption 內容:", res[0].get('caption'))

with open('./CONCH/who4e/for_demo/gts.json', 'r') as f:
    gts = json.load(f)
    print("\ngts.json 索引 2:", gts.get('2') or gts.get(2))
# Out:
# res_1112.json 第一個樣本: {'number': '9800', 'model': './CONCH/who4e/for_demo/projector_best_0928.pt', 'caption': 'Pathologic diagnosis: Lymphoid tumours of the lacrimal gland, classified as Haematolymphoid tumours within the broader category of Haematolymphoid tumours and haemangiomas\nMicroscopic findings: High-grade myelodysplastic syndrome (HRMDS) with diffuse large B-cell lymphoma. The tumor cells are arranged in a single sheet and display pleomorphism, mitoses and necrosis. The lymph nodes show high-grade'}
# caption 類型: <class 'str'>
# caption 內容: Pathologic diagnosis: Lymphoid tumours of the lacrimal gland, classified as Haematolymphoid tumours within the broader category of Haematolymphoid tumours and haemangiomas
# Microscopic findings: High-grade myelodysplastic syndrome (HRMDS) with diffuse large B-cell lymphoma. The tumor cells are arranged in a single sheet and display pleomorphism, mitoses and necrosis. The lymph nodes show high-grade
#
# ...

# %%
# !apt-get update && apt-get install -y openjdk-11-jre
# Out:
# Reading package lists... Done
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
